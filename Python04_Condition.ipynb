# %%
#Python04_Condition(1)
a = 33
b = 200
if b > a:
 print("b is greater than a")
# Out:
# b is greater than a

# %%
#Python04_Condition(2)
number = 15
if number > 0:
 print("The number is positive")
# Out:
# The number is positive

# %%
#Python04_Condition(3)
a = 33
b = 33
if b > a:
 print("b is greater than a")
elif a == b:
 print("a and b are equal")
# Out:
# a and b are equal

# %%
#Python04_Condition(4)
score = 75
if score >= 90:
 print("Grade: A")
elif score >= 80:
 print("Grade: B")
elif score >= 70:
 print("Grade: C")
elif score >= 60:
 print("Grade: D")
# Out:
# Grade: C

# %%
#Python04_Condition(5)
day = 3
if day == 1:
 print("Monday")
elif day == 2:
 print("Tuesday")
elif day == 3:
 print("Wednesday")
elif day == 4:
 print("Thursday")
elif day == 5:
 print("Friday")
elif day == 6:
 print("Saturday")
elif day == 7:
 print("Sunday")
# Out:
# Wednesday

# %%
#Python04_Condition(6)
a = 200
b = 33
if b > a:
 print("b is greater than a")
elif a == b:
 print("a and b are equal")
else:
 print("a is greater than b")
# Out:
# a is greater than b

# %%
#Python04_Condition(7)
number = 7
if number % 2 == 0:
 print("The number is even")
else:
 print("The number is odd")
# Out:
# The number is odd

# %%
#Python04_Condition(8)
a = 5
b = 2
if a > b: print("a is greater than b")
# Out:
# a is greater than b

# %%
#Python04_Condition(9)
a = 10
b = 20
bigger = a if a > b else b
print("Bigger is", bigger)
# Out:
# Bigger is 20

# %%
#Python04_Condition(10)
a = 33
b = 200
if not a > b:
 print("a is NOT greater than b")
# Out:
# a is NOT greater than b

# %%
#Python04_Condition(11)
x = 41
if x > 10:
 print("Above ten,")
 if x > 20:
    print("and also above 20!")
 else:
    print("but not above 20.")
# Out:
# Above ten,
# and also above 20!

# %%
#Python04_Condition(12)
fruits = ["apple", "banana", "cherry"]
for x in fruits:
 print(x)
# Out:
# apple
# banana
# cherry
